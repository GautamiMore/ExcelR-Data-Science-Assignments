# %% [markdown]
# # Set 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data={'name':['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers',
      'Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways',
      'Warner-Lambert'],'measure%':[24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00]}
df=pd.DataFrame(data)

# %%
df
# Out:
#                 name  measure%
# 0      Allied Signal     24.23
# 1      Bankers Trust     25.53
# 2      General Mills     25.41
# 3     ITT Industries     24.14
# 4   J.P.Morgan & Co.     29.62
# 5    Lehman Brothers     28.25
# 6           Marriott     25.81
# 7                MCI     24.39
# 8      Merrill Lynch     40.26
# 9          Microsoft     32.95
# 10    Morgan Stanley     91.36
# 11  Sun Microsystems     25.99
# 12         Travelers     39.42
# 13        US Airways     26.71
# 14    Warner-Lambert     35.00

# %%
df.plot(kind='bar',x='name',y='measure%',color='Blue')
# Out:
# <Axes: xlabel='name'>

# %%
plt.pie(df['measure%'],labels=df.name)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d477e30bd0>,
# ...
#  [Text(1.087229608003385, 0.16712803319852174, 'Allied Signal'),
#   Text(0.9828289461480074, 0.4940113992749534, 'Bankers Trust'),
#   Text(0.7770213716923852, 0.7786127329637529, 'General Mills'),
#   Text(0.500589114389161, 0.9794950426393569, 'ITT Industries'),
#   Text(0.14701343081593748, 1.09013166689154, 'J.P.Morgan & Co.'),
#   Text(-0.25102787165672724, 1.0709738594622624, 'Lehman Brothers'),
#   Text(-0.5940932351165659, 0.9257716932315078, 'Marriott'),
#   Text(-0.852379310544051, 0.6953053364935786, 'MCI'),
#   Text(-1.057980932673138, 0.30112513362400867, 'Merrill Lynch'),
#   Text(-1.0815202792052954, -0.20078318073907453, 'Microsoft'),
#   Text(-0.6253838571430779, -0.9049281911979793, 'Morgan Stanley'),
#   Text(0.14694509767976283, -1.0901408800094992, 'Sun Microsystems'),
#   Text(0.57095205164786, -0.9402200565394782, 'Travelers'),
#   Text(0.902381559110251, -0.6290528767740856, 'US Airways'),
# ...

# %%
df.describe()
# Out:
#         measure%
# count  15.000000
# mean   33.271333
# std    16.945401
# min    24.140000
# 25%    25.470000
# 50%    26.710000
# 75%    33.975000
# max    91.360000

# %%
df.var()
# Out:
# C:\Users\LENOVO SSD\AppData\Local\Temp\ipykernel_8532\1568254755.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# measure%    287.146612
# dtype: float64

# %%
plt.boxplot(df['measure%'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d477f7bd90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d478ac2c10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d477f78490>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d478ac3d50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d478ad85d0>],
#  'means': []}

# %% [markdown]
# # Set 2

# %% [markdown]
# # Q.1

# %%
import scipy.stats as stats

# %%
p1= 1- stats.norm.cdf(60,loc=55,scale=8)
p1
# Out:
# 0.26598552904870054

# %% [markdown]
# # Q.2 A)

# %%
p2= 1- stats.norm.cdf(44, loc=38, scale=6)
p2
# Out:
# 0.15865525393145707

# %%
p3= stats.norm.cdf(44, loc=38, scale=6)- stats.norm.cdf(38, loc=38, scale=6)
p3
# Out:
# 0.3413447460685429

# %% [markdown]
# # Q.2 B)

# %%
p4= stats.norm.cdf(30, loc=38, scale=6)
p4
# Out:
# 0.09121121972586788

# %%
36/400
# Out:
# 0.09

# %% [markdown]
# # Q.4

# %%
stats.norm.interval(0.99, loc = 100, scale = 20)
# Out:
# (48.48341392902199, 151.516586070978)

# %% [markdown]
# # Q.5

# %%
#A
np.round(stats.norm.interval(0.95, loc = 12, scale = 5),1)
# Out:
# array([ 2.2, 21.8])

# %%
2.2*45
# Out:
# 99.00000000000001

# %%
21.8*45
# Out:
# 981.0

# %%
#B
x=(12*45)+ (-1.645)*(5*45)
x
# Out:
# 169.875

# %%
#C
stats.norm.cdf(0,5,3)
# Out:
# 0.0477903522728147

# %%
stats.norm.cdf(0,7,4)
# Out:
# 0.040059156863817086

# %% [markdown]
# # Set 4

# %% [markdown]
# # Q.3

# %%
import scipy.stats as stats

# %%
(55-50)/(40/10)
# Out:
# 1.25

# %%
(45-50)/(40/10)
# Out:
# -1.25

# %%
p=stats.norm.cdf(1.25)- stats.norm.cdf(-1.25)
p
# Out:
# 0.7887004526662893

# %%
1-p
# Out:
# 0.2112995473337107
